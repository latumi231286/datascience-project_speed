# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

rootFolder = "/home/giangtm/Work/Projects/DataScience/dataset/"
d= pd.read_csv(rootFolder + "Project_Scheduling.csv")
d.sort_values(['project_type', 'project_name'], ascending=[False, True], inplace=True)
d.head()
# Out:
#                   project_Id                                   project_name  \
# 5   59a7b0b7fc13ae562a0002c1                001_140102_Ancestry_42882_Texas
# 6   59a7b0b7fc13ae562a0002c2     001_160108_Ancestry_45741_Lutheran_Bayern3
# 8   59a7b0b8fc13ae562a0002c4  001_170106_Ancestry_47392_EN_UPDATE_RoyalNavy
# 13  59a7b0b8fc13ae562a0002c9                         002_130103_SAGA_504510
# 14  59a7b0b8fc13ae562a0002ca                 002_140102_Ancestry_41548_NARA
#
#    project_type      step  backlog   speed  remaining_time  needed_fte
# 5    Type_Proof    Rework     1237  146.74           50.42        6.07
# 6    Type_Proof  Classify      930  380.57           98.31       11.84
# 8    Type_Proof    Rework     1240  341.57          117.65       14.17
# 13   Type_Proof   Capture      615  179.25           30.62        3.69
# 14   Type_Proof    Rework       51   39.15            0.55        0.07
